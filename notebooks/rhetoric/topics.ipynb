# %%
# !git clone https://github.com/average-peruvian/media-framing.git
# !mv media-framing/* .
# !rm -rf media-framing
# !pip install -e . -q
# !pip install bertopic sentence-transformers hdbscan umap-learn -q

# !wget -q https://github.com/average-peruvian/media-framing/releases/download/v0-alpha1/noticias_relevantes.csv

# %%
from google.colab import drive
drive.mount('/content/drive')

DRIVE_OUT = '/content/drive/MyDrive/ant/selection/out'

# %%
from medianalysis.rhetoric.topics import fit_topics

topic_model = fit_topics(
    cuerpo_csv='noticias_relevantes.csv',
    output_docs_csv=f'{DRIVE_OUT}/topics_por_doc.csv',
    output_topics_csv=f'{DRIVE_OUT}/topics_keywords.csv',
)
